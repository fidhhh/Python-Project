# %% [markdown]
# <a href="https://colab.research.google.com/github/fidhhh/Python-Project/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Final Project**
# By Hafidh Azizah
#
# The dataset contains 946 books obtained from scraping Amazon books related to data science, statistics, data analysis, Python, deep learning, and machine learning.
# There are 18 columns:
#
#
# *  `title`: title of the book
# *  `author`: author (or the authors) of the book
# *  `price`: price (in dollars)
# *  `pages`: number of pages
# *  `avg_reviews`: average reviews (out of 5)
# *  `n_reviews`: reviews done for each book
# *  `star5`: percentage of 5 star reviews
# *  `star4`: percentage of 4 star reviews
# *  `star3`: percentage of 3 star reviews
# *  `star2`: percentage of 2 star reviews
# *  `star1`: percentage of 1 star reviews
# *  `dimensions`: size of the book (in inches)
# *  `weight`: weight (in pounds or ounces)
# *  `language`: language of the book
# *  `publisher`: publisher
# *  `ISBN-13`: ISBN_13 code
#
# `link`: link of the Amazon book (including the domain https://amazon.com)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/final_book_dataset_kaggle.csv')

# %%
data.head()
# Out:
#                                                title  \
# 0  Becoming a Data Head: How to Think Speak and U...
# 1  Ace the Data Science Interview: 201 Real Inter...
# 2  Fundamentals of Data Engineering: Plan and Bui...
# 3  Essential Math for Data Science: Take Control ...
# 4  Data Science for Business: What You Need to Kn...
#
#                               author  price  pages  avg_reviews  n_reviews  \
# 0  [Alex J. Gutman,Jordan Goldmeier]  24.49  272.0          4.6        184
# 1             [Nick Singh,Kevin Huo]  26.00  301.0          4.5        599
# 2            [Joe Reis,Matt Housley]  50.76  446.0          5.0         33
# 3                     [Thomas Nield]  44.80  347.0          4.5         27
# 4       [Foster Provost,Tom Fawcett]  36.99  413.0          4.5        970
#
#    star5  star4  star3  star2  star1             dimensions       weight  \
# 0   0.74   0.18   0.05   0.02   0.01    6 x 0.62 x 9 inches  12.5 ounces
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 946 entries, 0 to 945
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          946 non-null    object
#  1   author         824 non-null    object
#  2   price          944 non-null    float64
#  3   pages          934 non-null    float64
#  4   avg_reviews    823 non-null    float64
#  5   n_reviews      946 non-null    int64
#  6   star5          946 non-null    float64
#  7   star4          946 non-null    float64
#  8   star3          946 non-null    float64
#  9   star2          946 non-null    float64
#  10  star1          946 non-null    float64
#  11  dimensions     914 non-null    object
#  12  weight         943 non-null    object
#  13  language       943 non-null    object
#  14  publisher      942 non-null    object
#  15  ISBN_13        945 non-null    object
#  16  link           946 non-null    object
# ...

# %%
data.shape
# Out:
# (946, 18)

# %%
data.isnull().sum()
# Out:
# title              0
# author           122
# price              2
# pages             12
# avg_reviews      123
# n_reviews          0
# star5              0
# star4              0
# star3              0
# star2              0
# star1              0
# dimensions        32
# weight             3
# language           3
# publisher          4
# ISBN_13            1
# link               0
# complete_link      0
# dtype: int64

# %%
new_data = data.dropna(subset=["author", "price", "pages", "avg_reviews", "dimensions", "weight", "language", "publisher", "ISBN_13"], axis=0)

# %%
new_data.shape
# Out:
# (698, 18)

# %%
new_data.tail()
# Out:
#                                                  title  \
# 941  The Book of R: A First Course in Programming a...
# 942  Basic Business Statistics: A Casebook (Textboo...
# 943         Elementary Statistics: Picturing the World
# 944  Making Sense of Statistics: A Conceptual Overview
# 945                  Psychology Statistics For Dummies
#
#                                       author   price  pages  avg_reviews  \
# 941                       [Tilman M. Davies]   28.33  832.0          4.6
# 942  [Dean P. Foster,Robert A. Stine et al.]   59.23  260.0          4.3
# 943                [Ron Larson,Betsy Farber]  129.99  704.0          4.5
# 944             [Fred Pyrczak,Deborah M. Oh]   47.76  252.0          4.6
# 945          [Donncha Hanna,Martin Dempster]   15.55  464.0          4.5
#
#      n_reviews  star5  star4  star3  star2  star1                 dimensions  \
# 941        327   0.74   0.16   0.06   0.02   0.03     7 x 1.44 x 9.25 inches
# ...

# %%
new_data.describe()
# Out:
#             price        pages  avg_reviews    n_reviews       star5  \
# count  698.000000   698.000000   698.000000   698.000000  698.000000
# mean    50.454513   430.237822     4.444556   150.881089    0.719140
# std     36.399546   204.349437     0.401976   535.166053    0.150545
# min      8.990000    48.000000     1.000000     1.000000    0.110000
# 25%     31.967500   286.250000     4.300000    10.000000    0.620000
# 50%     41.990000   392.000000     4.500000    33.000000    0.720000
# 75%     51.840000   543.500000     4.700000   101.750000    0.800000
# max    279.950000  1728.000000     5.000000  7563.000000    1.000000
#
#             star4       star3       star2       star1
# count  698.000000  698.000000  698.000000  698.000000
# mean     0.162020    0.067049    0.030444    0.021261
# std      0.105296    0.063199    0.040292    0.033373
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.110000    0.000000    0.000000    0.000000
# ...

# %%
new_data.dtypes
# Out:
# title             object
# author            object
# price            float64
# pages            float64
# avg_reviews      float64
# n_reviews          int64
# star5            float64
# star4            float64
# star3            float64
# star2            float64
# star1            float64
# dimensions        object
# weight            object
# language          object
# publisher         object
# ISBN_13           object
# link              object
# complete_link     object
# dtype: object

# %%
new_data["n_reviews"] = new_data["n_reviews"].astype("float64")
new_data.dtypes
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# title             object
# author            object
# price            float64
# pages            float64
# avg_reviews      float64
# n_reviews        float64
# star5            float64
# star4            float64
# star3            float64
# star2            float64
# star1            float64
# dimensions        object
# weight            object
# language          object
# publisher         object
# ISBN_13           object
# link              object
# complete_link     object
# dtype: object

# %%
new_data.groupby(['title'])["price", "avg_reviews"].agg([max,min,sum])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                                      price                  \
#                                                        max     min     sum
# title
# 5 Steps to a 5: AP Statistics 2022                   18.00   18.00   18.00
# 97 Things About Ethics Everyone in Data Science...   30.99   30.99   30.99
# A Common-Sense Guide to Data Structures and Alg...   39.71   39.71   39.71
# A First Course in Machine Learning (Chapman & H...   43.96   43.96   43.96
# A Gentle Introduction to Stata                       69.56   69.56   69.56
# ...                                                    ...     ...     ...
# Using Python for Principles of Econometrics          29.40   29.40   29.40
# ...

# %%
new_data.pivot_table(index=['language', 'title'], aggfunc='mean')
# Out:
#                                                              avg_reviews  \
# language title
# English  5 Steps to a 5: AP Statistics 2022                          4.7
#          97 Things About Ethics Everyone in Data Science...          4.1
#          A Common-Sense Guide to Data Structures and Alg...          4.7
#          A First Course in Machine Learning (Chapman & H...          4.4
#          A Gentle Introduction to Stata                              4.6
# ...                                                                  ...
#          Using SPSS for Windows and Macintosh (7th Edition)          4.4
#          Video Data Analysis: How to Use 21st Century Vi...          5.0
#          Violent Python: A Cookbook for Hackers Forensic...          4.5
#          Web Development with Django: Learn to build mod...          4.5
# Spanish  El lenguaje de programaciÃ³n Python de principi...          5.0
#
# ...

# %%
new_data.sort_values(by="avg_reviews", ascending=False)
# Out:
#                                                  title  \
# 594            Automated Machine Learning for Business
# 143                              Learning Tableau 2022
# 329  In-Memory Analytics with Apache Arrow: Perform...
# 317  Adverse Impact Analysis: Understanding Data St...
# 661  Data Algorithms with Spark: Recipes and Design...
# ..                                                 ...
# 904  Statistics and Data Visualization Using R: The...
# 914  Statistics and Probability with Applications (...
# 461  Implement NLP use-cases using BERT: Explore th...
# 480  Deep Learning Pipeline: Building a Deep Learni...
# 160  Applied Data Science: Lessons Learned for the ...
#
#                                            author   price  pages  avg_reviews  \
# 594              [Kai R. Larsen,Daniel S. Becker]   45.00  352.0          5.0
# 143  [Joshua N. Milligan,Blair Hutchinson et al.]   55.09  566.0          5.0
# ...

# %%
new_data.sort_values(by="price", ascending=False)
# Out:
#                                                  title  \
# 885  Using SPSS for Windows and Macintosh (7th Edit...
# 917                                         Statistics
# 867         Introduction to the Practice of Statistics
# 850              Statistics for Business and Economics
# 920  Statistics for Business: Decision Making and A...
# ..                                                 ...
# 320   Python for Everybody: Exploring Data in Python 3
# 378  Hands on Azure Data Studio: Microsofts Open Pl...
# 911  Essential Calculus Skills Practice Workbook wi...
# 916  Learn Calculus Quickly: The Complete Guide To ...
# 887  How to Work With Probability and Statistics Gr...
#
#                                                 author   price  pages  \
# 885                  [Samuel B. Green,Neil J. Salkind]  279.95  448.0
# 917                      [James McClave,Terry Sincich]  253.32  896.0
# 867           [David S. Moore,George P. McCabe et al.]  240.34  784.0
# ...

# %%
new_data.loc[:, "title"]
# Out:
# 0      Becoming a Data Head: How to Think Speak and U...
# 1      Ace the Data Science Interview: 201 Real Inter...
# 2      Fundamentals of Data Engineering: Plan and Bui...
# 3      Essential Math for Data Science: Take Control ...
# 4      Data Science for Business: What You Need to Kn...
#                              ...
# 941    The Book of R: A First Course in Programming a...
# 942    Basic Business Statistics: A Casebook (Textboo...
# 943           Elementary Statistics: Picturing the World
# 944    Making Sense of Statistics: A Conceptual Overview
# 945                    Psychology Statistics For Dummies
# Name: title, Length: 698, dtype: object

# %%
new_data.iloc[4, :]
# Out:
# title            Data Science for Business: What You Need to Kn...
# author                                [Foster Provost,Tom Fawcett]
# price                                                        36.99
# pages                                                        413.0
# avg_reviews                                                    4.5
# n_reviews                                                    970.0
# star5                                                         0.71
# star4                                                         0.15
# star3                                                         0.08
# star2                                                         0.03
# star1                                                         0.03
# dimensions                                   7 x 0.9 x 9.19 inches
# weight                                                  1.5 pounds
# language                                                   English
# ...

# %%
sns.distplot(new_data['price'])
plt.plot()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# []

# %%
sns.distplot(new_data['avg_reviews'])
plt.plot()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# []

# %%
sns.boxplot(data=new_data)

# %%
new_data.avg_reviews.value_counts(ascending=True).plot(kind = 'bar');

# %% [markdown]
# # Conclusion
#
# 1.  Judul buku Using SPSS for Windows and Macintosh karya Samuel B. Green and Neil J. Salkind yang memiliki harga tertinggi, rata-rata hanya memiliki 4,4 star reviews dari para pembaca.
# 2.  Harga dari sebuah buku tidak menjamin kepuasan para pembaca dalam menggunakan buku tersebut.
# 3.  Sedangkan rata-rata reviews tertinggi yang mencapai 5 star, yaitu buku berjudul Automated Machine Learning for Business karya Kai R. Larsen and Daniel S. Becker hanya memiliki harga dibawah 50 dollar.
# 4.  Beberapa buku tentang data science memiliki daya tarik tersendiri untuk para pembacanya, dari dataset di atas rata-rata reviews pembaca tertinggi yaitu buku tentang machine learning. Namun itu tergantung dengan kebutuhan buku apa yang kita perlukan dan seberapa berkualitasnya buku tersebut. Sehingga membuat para pembaca tertarik dan memberikan reviews yang bagus tentang buku yang dibacanya.
# 5.  Dari reviews para pembaca inilah, kita akan tahu di masa depan nanti buku mana yang bagus dan terpercaya.
