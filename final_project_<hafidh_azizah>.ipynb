# %% [markdown]
# <a href="https://colab.research.google.com/github/fidhhh/Python-Project/blob/main/final_project_%3Chafidh_azizah%3E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.style.use('seaborn')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib/style/core.py in use(style)
#     136             try:
# --> 137                 style = _rc_params_in_file(style)
#     138             except OSError as err:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in _rc_params_in_file(fname, transform, fail_on_error)
#     865     rc_temp = {}
# --> 866     with _open_file_or_url(fname) as fd:
#     867         try:
#
# /usr/lib/python3.10/contextlib.py in __enter__(self)
#     134         try:
# --> 135             return next(self.gen)
#     136         except StopIteration:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in _open_file_or_url(fname)
#     842         fname = os.path.expanduser(fname)
# --> 843         with open(fname, encoding='utf-8') as f:
#     844             yield f
#
# ...

# %%
df_employee = pd.read_csv('/content/The Impact of Electronic Gadget Uses with Academic Performance among University Students (Responses) - Form Responses 1 (1).csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-81ef805ffa01> in <cell line: 1>()
# ----> 1 df_employee = pd.read_csv('/content/The Impact of Electronic Gadget Uses with Academic Performance among University Students (Responses) - Form Responses 1 (1).csv')
#
# ...

# %%
df_employee.shape
# Out:
# (30, 9)

# %%
df_employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                   --------------  -----
#  0   Timestamp                                                                                30 non-null     object
#  1   Gender                                                                                   30 non-null     object
#  2   Your study year                                                                          30 non-null     object
#  3   Which department                                                                         30 non-null     object
#  4   How many electronic devices do you use?                                                  30 non-null     int64
# ...

# %%
df_employee.duplicated().any()
# Out:
# False

# %%
df_employee.tail()
# Out:
#             Timestamp  Gender Your study year  \
# 25  9/16/2022 2:11:03  Female               3
# 26  9/16/2022 2:13:15  Female               4
# 27  9/16/2022 2:13:55    Male               1
# 28  9/16/2022 2:14:50  Female   Post Graduate
# 29  9/16/2022 2:15:34  Female               4
#
#                     Which department  How many electronic devices do you use?  \
# 25            Information Technology                                        3
# 26  Architecture & Built Environment                                        2
# 27            Allied Health Sciences                                        2
# 28               Creative Industries                                        4
# 29               Business Management                                        4
#
#    What is your recent latest CGPA ? Is there an increase in your CGPA?  \
# 25                         2.50-2.99                               None
# ...

# %%
df_employee.isnull().sum()
# Out:
# Timestamp                                                                                  0
# Gender                                                                                     0
# Your study year                                                                            0
# Which department                                                                           0
# How many electronic devices do you use?                                                    0
# What is your recent latest CGPA ?                                                          0
# Is there an increase in your CGPA?                                                         0
# Average hour you spent using electronic devices for academic purposes in a day (hours).    0
# What is the purpose of buying the device?                                                  0
# dtype: int64

# %%
df_employee.describe()
# Out:
#        How many electronic devices do you use?
# count                                30.000000
# mean                                  2.566667
# std                                   0.817200
# min                                   1.000000
# 25%                                   2.000000
# 50%                                   2.000000
# 75%                                   3.000000
# max                                   4.000000

# %%
df_employee.sum()
# Out:
# Timestamp                                                                                  7/19/2022 12:26:347/21/2022 2:19:267/21/2022 1...
# Gender                                                                                     FemaleMaleMaleFemaleMaleMaleFemaleMaleMaleMale...
# Your study year                                                                            4Post Graduate33214Post Graduate44123134Post G...
# Which department                                                                           Information TechnologyBusiness ManagementInfor...
# How many electronic devices do you use?                                                                                                   77
# What is your recent latest CGPA ?                                                          3.00-3.493.00-3.493.50 - 3.992.50-2.993.00-3.4...
# ...

# %%
df_employee.iloc[3, :]
# Out:
# Timestamp                                                                                                                 8/22/2022 10:01:30
# Gender                                                                                                                                Female
# Your study year                                                                                                                            3
# Which department                                                                                                                 Engineering
# How many electronic devices do you use?                                                                                                    3
# What is your recent latest CGPA ?                                                                                                  2.50-2.99
# ...

# %%
# Out:
# 0               Information Technology
# 1                  Business Management
# 2               Information Technology
# 3                          Engineering
# 4     Architecture & Built Environment
# 5                  Creative Industries
# 6                  Business Management
# 7               Information Technology
# 8          Education & Liberal Studies
# 9                Hospitality & Tourism
# 10                         Engineering
# 11              Allied Health Sciences
# 12    Architecture & Built Environment
# 13                 Creative Industries
# 14                 Creative Industries
# 15                 Business Management
# 16         Education & Liberal Studies
# 17               Hospitality & Tourism
# 18                         Engineering
# 19                 Business Management
# 20              Information Technology
# 21               Hospitality & Tourism
# 22         Education & Liberal Studies
# 23                 Business Management
# ...

# %%
df_employee.dtypes
# Out:
# Timestamp                                                                                  object
# Gender                                                                                     object
# Your study year                                                                            object
# Which department                                                                           object
# How many electronic devices do you use?                                                     int64
# What is your recent latest CGPA ?                                                          object
# Is there an increase in your CGPA?                                                         object
# Average hour you spent using electronic devices for academic purposes in a day (hours).    object
# What is the purpose of buying the device?                                                  object
# dtype: object

# %%
df_employee["How many electronic devices do you use?"] = df_employee["How many electronic devices do you use?"].astype("float64")
df_employee.dtypes
# Out:
# Timestamp                                                                                   object
# Gender                                                                                      object
# Your study year                                                                             object
# Which department                                                                            object
# How many electronic devices do you use?                                                    float64
# What is your recent latest CGPA ?                                                           object
# Is there an increase in your CGPA?                                                          object
# Average hour you spent using electronic devices for academic purposes in a day (hours).     object
# What is the purpose of buying the device?                                                   object
# dtype: object

# %%
df_employee.max()
# Out:
# Timestamp                                                                                                                 9/16/2022 2:15:34
# Gender                                                                                                                                 Male
# Your study year                                                                                                               Post Graduate
# Which department                                                                                                     Information Technology
# How many electronic devices do you use?                                                                                                 4.0
# What is your recent latest CGPA ?                                                                                               3.50 - 3.99
# Is there an increase in your CGPA?                                                                                                 decrease
# ...

# %%
df_employee.min()
# Out:
# Timestamp                                                                                                7/19/2022 12:26:34
# Gender                                                                                                               Female
# Your study year                                                                                                           1
# Which department                                                                                     Allied Health Sciences
# How many electronic devices do you use?                                                                                 1.0
# What is your recent latest CGPA ?                                                                                 2.00-2.49
# Is there an increase in your CGPA?                                                                                 Increase
# ...

# %%
df_employee.groupby(['Gender', 'Which department'])["How many electronic devices do you use?"].agg([max,min,sum])
# Out:
#                                          max  min  sum
# Gender Which department
# Female Architecture & Built Environment  2.0  2.0  2.0
#        Business Management               4.0  1.0  9.0
#        Creative Industries               4.0  4.0  4.0
#        Engineering                       3.0  3.0  6.0
#        Hospitality & Tourism             3.0  3.0  3.0
#        Information Technology            3.0  2.0  7.0
# Male   Allied Health Sciences            3.0  2.0  5.0
#        Architecture & Built Environment  2.0  2.0  4.0
#        Business Management               4.0  2.0  9.0
#        Creative Industries               4.0  2.0  8.0
#        Education & Liberal Studies       2.0  2.0  6.0
#        Engineering                       2.0  2.0  4.0
#        Hospitality & Tourism             2.0  2.0  4.0
#        Information Technology            3.0  3.0  6.0

# %%
df_employee.pivot_table(index=['Gender', 'Which department'], aggfunc='mean')
# Out:
#                                          How many electronic devices do you use?
# Gender Which department
# Female Architecture & Built Environment                                 2.000000
#        Business Management                                              3.000000
#        Creative Industries                                              4.000000
#        Engineering                                                      3.000000
#        Hospitality & Tourism                                            3.000000
#        Information Technology                                           2.333333
# Male   Allied Health Sciences                                           2.500000
#        Architecture & Built Environment                                 2.000000
#        Business Management                                              3.000000
#        Creative Industries                                              2.666667
# ...

# %%
df_employee.drop(columns=['Timestamp'])
# Out:
#     Gender Your study year                  Which department  \
# 0   Female               4            Information Technology
# 1     Male   Post Graduate               Business Management
# 2     Male               3            Information Technology
# 3   Female               3                       Engineering
# 4     Male               2  Architecture & Built Environment
# 5     Male               1               Creative Industries
# 6   Female               4               Business Management
# 7     Male   Post Graduate            Information Technology
# 8     Male               4       Education & Liberal Studies
# 9     Male               4             Hospitality & Tourism
# 10    Male               1                       Engineering
# 11    Male               2            Allied Health Sciences
# 12    Male               3  Architecture & Built Environment
# 13    Male               1               Creative Industries
# ...

# %%
sns.distplot(df_employee['How many electronic devices do you use?'])
plt.plot()
# Out:
# []

# %%
sns.boxplot()

# %%
df.to_csv("automobile_data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-03f5ab2b972b> in <cell line: 1>()
# ----> 1 df.to_csv("automobile_data.csv", index=False)
#
# NameError: name 'df' is not defined

# %% [markdown]
# Conclusion
# 1. Penggunaan gadget terbanyak yaitu berjumlah 4, berasal dari seorang perempuan dari industri kreatif.
# 2. Rata-rata pengunaan gadget tertinggi sekitar 13-15 jam.
# 3. Selain untuk belajar maupun online class, penggunaan gadget ini juga sering digunakan untuk entertainment maupun games online.
# 4. Untuk pelajar terutama mahasiswa, gadget sangat dibutuhkan terutama semenjak pandemi pembelajaran sudah beralih via online sehingga keberadaan dari gadget ini sangat membantu.
# 5. Saat ini penggunaan devices sudah tidak diragukan lagi, banyak kalangan yang sudah menggunakan perangkat electronic terutama handphone dan penggunaannya tidak memandang usia baik dari kalangan muda sampai orang tua.
